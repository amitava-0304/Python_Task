# %% [markdown]
# # 1 . Write a program to insert a record in sql table via api database

# %% [markdown]
# ![Q1.JPG](attachment:Q1.JPG)

# %% [markdown]
# # 2.  Write a program to update a record via api

# %% [markdown]
# ![Q3.JPG](attachment:Q3.JPG)

# %% [markdown]
# # 3 . Write a program to delete a record via api

# %% [markdown]
# ![Q4.JPG](attachment:Q4.JPG)

# %% [markdown]
# # 4 . Write a program to fetch a record via api

# %% [markdown]
# ![fetch.JPG](attachment:fetch.JPG)

# %% [markdown]
# # 1 . Write a program to insert a record in mongodb table via api database

# %% [markdown]
# ![mongo_API_Q1.JPG](attachment:mongo_API_Q1.JPG)

# %% [markdown]
# ![mongodb_Q1.JPG](attachment:mongodb_Q1.JPG)

# %% [markdown]
# # 2.  Write a program to update a record via api

# %% [markdown]
# ![mongo_API_update.JPG](attachment:mongo_API_update.JPG)

# %% [markdown]
# ![mongodb_update.JPG](attachment:mongodb_update.JPG)

# %% [markdown]
# # 3 . Write a program to delete a record via api

# %% [markdown]
# ![mongo_API_delete.JPG](attachment:mongo_API_delete.JPG)

# %% [markdown]
# # 4 . Write a program to fetch a record via api

# %% [markdown]
# ![mongo_API_search.JPG](attachment:mongo_API_search.JPG)
